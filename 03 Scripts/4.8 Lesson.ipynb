# %%
import pandas as pd 
import numpy as np
import os

# %%
df_ords_prod_merge = pd.read_csv(r"C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\orders_products_combined.csv", index_col = False)

# %%
df_merged_large = pd.read_pickle(r"C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\df_merged_large.pkl")

# %%
df=df_merged_large[:1000000]

# %%
df_1=df_ords_prod_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(10)
# Out:
#    Unnamed: 0_x  Unnamed: 0.1  order_id  customer_number  order_number_x  \
# 0             1             1   2398795                1               2
# 1             1             1   2398795                1               2
# 2             1             1   2398795                1               2
# 3             1             1   2398795                1               2
# 4             1             1   2398795                1               2
# 5             1             1   2398795                1               2
# 6             2             2    473747                1               3
# 7             2             2    473747                1               3
# 8             2             2    473747                1               3
# 9             2             2    473747                1               3
#
#    orders_day_of_week  order_hour_of_day_x  days_since_prior_order_x  \
# 0                   3                    7                      15.0
# ...

# %%
df_1.head(5)
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           1   2539329        1    prior             1          2
# 2           2   2539329        1    prior             1          2
# 3           3   2539329        1    prior             1          2
# 4           4   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df.groupby('product_id')

# %%
df.groupby('order_dow').agg({'product_id':['mean']})
# Out:
#              product_id
#                    mean
# order_dow
# 0          25659.621850
# 1          25586.506097
# 2          25450.134506
# 3          25525.787779
# 4          25562.695618
# 5          25574.013634
# 6          25627.234996

# %%
df.groupby('order_dow')['product_id'].mean()
# Out:
# order_dow
# 0    25659.621850
# 1    25586.506097
# 2    25450.134506
# 3    25525.787779
# 4    25562.695618
# 5    25574.013634
# 6    25627.234996
# Name: product_id, dtype: float64

# %%
df.groupby('order_dow').agg({'add_to_cart_order': ['mean', 'min', 'max']})
# Out:
#           add_to_cart_order
#                        mean min max
# order_dow
# 0                  8.676322   1  74
# 1                  8.327949   1  75
# 2                  8.073795   1  95
# 3                  7.798243   1  71
# 4                  8.016449   1  63
# 5                  8.304226   1  72
# 6                  8.644768   1  66

# %%
df_ords_prod_merge['max_order'] = df_ords_prod_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prod_merge.head(5)
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           1   2539329        1    prior             1          2
# 2           2   2539329        1    prior             1          2
# 3           3   2539329        1    prior             1          2
# 4           4   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge  max_order
# 0          0   both         10
# 1          0   both         10
# ...

# %%
df_ords_prod_merge.loc[df_ords_prod_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prod_merge.loc[(df_ords_prod_merge['max_order'] <= 40) & (df_ords_prod_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prod_merge.loc[df_ords_prod_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prod_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    2172054
# Loyal customer      1435409
# New customer         864817
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prod_merge[['user_id', 'loyalty_flag', 'order_number']].head(5)
# Out:
#    user_id  loyalty_flag  order_number
# 0        1  New customer             1
# 1        1  New customer             1
# 2        1  New customer             1
# 3        1  New customer             1
# 4        1  New customer             1

# %%
path = r"C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data"

# %%
df_ords_prod_merge.to_csv(os.path.join(path, 'df_ords_prod_merge.csv'))
