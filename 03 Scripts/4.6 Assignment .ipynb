# %%
import pandas as pd 
import numpy as np 
import os

# %% [markdown]
# # Assignment

# %%
#3
df_orders_pro_com = pd.read_pickle(r'C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\orders_products_combined.pkl')

# %%
#4
df_orders_pro_com.shape
# Out:
# (32434489, 11)

# %%
#5
df_combined_pro_com = pd.read_csv(r'C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\orders_products_combined.csv', index_col = False)

# %%
df_orders_clean = pd.read_csv(r'C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\orders_clean.csv', index_col = False)

# %%
df_merged_large = df_orders_clean.merge(df_combined_pro_com, on = ['order_id'])

# %%
df_merged_check = df_combined_pro_com.merge(df_orders_clean, on = ['order_id'])

# %%
df_merged_check
# Out:
#          Unnamed: 0_x  order_id  user_id eval_set  order_number_x  order_dow  \
# 0                   5   2398795        1    prior               2          3
# 1                   6   2398795        1    prior               2          3
# 2                   7   2398795        1    prior               2          3
# 3                   8   2398795        1    prior               2          3
# 4                   9   2398795        1    prior               2          3
# ...               ...       ...      ...      ...             ...        ...
# 4186298       4472275     25155    28476    prior              37          3
# 4186299       4472276     25155    28476    prior              37          3
# 4186300       4472277     25155    28476    prior              37          3
# 4186301       4472278   2097279    28476    prior              38          4
# 4186302       4472279   2097279    28476    prior              38          4
#
# ...

# %%
#6
df_merged_large
# Out:
#          Unnamed: 0_x  Unnamed: 0.1  order_id  customer_number  \
# 0                   1             1   2398795                1
# 1                   1             1   2398795                1
# 2                   1             1   2398795                1
# 3                   1             1   2398795                1
# 4                   1             1   2398795                1
# ...               ...           ...       ...              ...
# 4186298        472315        472315     25155            28476
# 4186299        472315        472315     25155            28476
# 4186300        472315        472315     25155            28476
# 4186301        472316        472316   2097279            28476
# 4186302        472316        472316   2097279            28476
#
#          order_number_x  orders_day_of_week  order_hour_of_day_x  \
# 0                     2                   3                    7
# 1                     2                   3                    7
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both    4186303
# Name: _merge, dtype: int64

# %%
#7
df_merged_large.to_pickle(r'C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\03 Scripts\df_merged_large.pkl')
