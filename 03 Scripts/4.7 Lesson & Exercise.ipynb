# %%
import pandas as pd
import numpy as np
import os

# %%
def add_num(x,y):
    sum = x+y
    return sum

# %%
add_num(9,11)
# Out:
# 20

# %%
df_merged_large = pd.read_pickle(r'C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\df_merged_large.pkl')

# %%
ord_prod_com = pd.read_pickle(r'C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\orders_products_combined.pkl')

# %%
products_checked = pd.read_csv(r'C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\products_checked.csv', index_col = False)

# %%
ord_prod_com_2 = pd.read_csv(r'C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data\orders_products_combined.csv', index_col = False)

# %%
# work with first million rows 
df = df_merged_large[:1000000]

# %%
df_1 = ord_prod_com[:1000000]

# %%
df_2 = products_checked[:1000000]

# %%
df_2.shape
# Out:
# (49672, 6)

# %%
def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range'
    else: return 'Not enough data'

# %%
df_2['price_range'] = df_2.apply(price_label, axis=1)
# Out:
# <ipython-input-12-6f1d58a67ce3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['price_range'] = df_2.apply(price_label, axis=1)

# %%
df_2['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    32831
# Low-range product    16294
# High range             547
# Name: price_range, dtype: int64

# %%
df_2['prices'].max()
# Out:
# 99999.0

# %%
df_2.loc[df_2['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# D:\ana\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# D:\ana\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_2.loc[(df_2['prices'] <= 15) & (df_2['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# D:\ana\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_2.loc[df_2['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# D:\ana\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_2['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     32831
# Low-range product     16294
# High-range product      547
# Name: price_range_loc, dtype: int64

# %%
ord_prod_com_2['order_dow'].value_counts(dropna = False)
# Out:
# 0    843819
# 1    774591
# 6    626054
# 5    587301
# 2    580668
# 3    534489
# 4    525358
# Name: order_dow, dtype: int64

# %%
result = []

for value in ord_prod_com_2['order_dow']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ord_prod_com_2['busiest_day'] = result

# %%
ord_prod_com_2['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    3103103
# Busiest day        843819
# Least busy         525358
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 4.7 Assignment

# %%
# 2

result_1 = []

for value in ord_prod_com_2['order_dow']:
    if value == 0:
        result_1.append('Busiest_days')
    elif value == 1:
        result_1.append('Busiest_days')
    elif value == 3:
        result_1.append('Slowest_days')
    elif value == 4:
        result_1.append('Slowest_days')
    else:
        result_1.append('Regularly Busy')

# %%
result_1
# Out:
# ['Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
# ...

# %%
ord_prod_com_2['Busiest_days'] = result_1

# %%
# 3

ord_prod_com_2['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly Busy    1794023
# Busiest_days      1618410
# Slowest_days      1059847
# Name: Busiest_days, dtype: int64

# %%
# The value adjustments that where added distribute the values differently now

# %%
# 4 

ord_prod_com_2['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    380562
# 11    376765
# 14    369432
# 13    368662
# 15    366202
# 12    363122
# 16    347164
# 9     338548
# 17    293110
# 8     237488
# 18    225413
# 19    174978
# 20    135082
# 7     124516
# 21    111157
# 22     87225
# 23     54500
# 6      39956
# 0      27979
# 1      14825
# 5      12387
# 2       8828
# 4       7700
# 3       6679
# Name: order_hour_of_day, dtype: int64

# %%
result_2 = []

for value in ord_prod_com_2['order_hour_of_day']:
    if value > 10 & value <=18:
        result_2.append('Most_orders')
    elif value <=5:
        result_2.append('Fewest_orders')
    else:
        result_2.append('Average_orders')

# %%
result_2
# Out:
# ['Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
# ...

# %%
ord_prod_com_2['Busiest_period_of_day'] = result_2

# %%
# 5

ord_prod_com_2['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most_orders       3817423
# Average_orders     618050
# Fewest_orders       36807
# Name: Busiest_period_of_day, dtype: int64

# %%
path = r"C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\03 Scripts"

# %%
ord_prod_com_2.to_pickle(os.path.join(path, 'ord_prod_com_2.pkl'))

# %%
path_2 = r"C:\Users\ms207\Desktop\CF\4\19012022 Instacart Basket Analysis\02 Data\Prepared data"

# %%
ord_prod_com_2.to_csv(os.path.join(path_2, 'ord_prod_com_2.csv'))
